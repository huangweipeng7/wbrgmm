# %%
import seaborn as sns
import pandas as pd
import numpy as np
import scipy

# %%
mu1, sig1 = [0, 0], [[1, 0], [0, 100]]
mu2, sig2 = [0, 0], [[100, 0], [0, 1]]
# mu3, sig3 = [4, 4], [[1, 0], [0, 1]]


a = np.random.multivariate_normal(mu1, sig1, 247)
b = np.random.multivariate_normal(mu2, sig2, 253)
# c = np.random.multivariate_normal(mu3, sig3, 100)

# %%
z = np.vstack([a, b])
df = pd.DataFrame({'x': z[:, 0], 'y': z[:, 1]})

# %%
df
# Out:
#              x          y
# 0     1.139780   2.600719
# 1    -1.026905  -1.093166
# 2     1.872215  10.980976
# 3     0.813053  -8.613802
# 4    -1.657764  -2.489910
# ..         ...        ...
# 495  -3.871763   0.552695
# 496 -11.932022   0.230758
# 497  12.926544  -0.624063
# 498  -3.079784   0.153459
# 499   0.732250   1.295783
#
# [500 rows x 2 columns]

# %%
sns.scatterplot(df, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
df.to_csv('../projects/wbrgmm/WassersteinBayesRepulsiveGMM/data/sim_data2.csv', index=False)

# %%
import scipy
np.random.seed(11)

m1 = np.array([0, 0])
m2 = np.array([0, 0]) 
sig1 = np.array([[100, 0], [0, 1]])
sig2 = np.array([[1, 0], [0, 100]])
sig3 = [[4, 1], [1, 4]]

K = 1
# ww = scipy.stats.dirichlet(np.ones(K)).rvs(1)
ww = [1/4, 1/4, 1/2]
nn = scipy.stats.multinomial.rvs(200, ww)
print(nn)

x1 = np.random.multivariate_normal(m1, sig1, nn[0])
x2 = np.random.multivariate_normal(m2, sig2, nn[1]) 
data = [x1, x2]

print(ww)
for n in nn[2:]: 
    m = np.random.multivariate_normal([0, 0], [[100, 0], [0, 100]])
    data.append(np.random.multivariate_normal(m, sig3, n))

z = np.vstack(data)

df = pd.DataFrame({'x': z[:, 0], 'y': z[:, 1]})
sns.scatterplot(df, x='x', y='y', alpha=0.5)
df.to_csv(
    '~/Workspace/projects/wbrgmm/WassersteinBayesRepulsiveGMM/data/sim_data_new_1.csv',
    index=False
)
# Out:
# [54 53 93]
# [0.25, 0.25, 0.5]

# %%
np.random.seed(222)

m1 = np.array([0, 0])
m2 = np.array([0, 0])
m3 = [-15, 0]
sig1 = np.array([[100, 0], [0, 1]])
sig2 = np.array([[1, 0], [0, 100]])
sig3 = [[4, 1], [1, 4]]

K = 2
# ww = scipy.stats.dirichlet(np.ones(K)).rvs(1)
ww = [1/6, 1/6, 1/3, 1/3]
nn = scipy.stats.multinomial.rvs(300, ww)
print(nn)

x1 = np.random.multivariate_normal(m1, sig1, nn[0])
x2 = np.random.multivariate_normal(m2, sig2, nn[1]) 
data = [x1, x2]

print(ww)
for n in nn[2:]: 
    m = np.random.multivariate_normal([0, 0], [[100, 0], [0, 100]])
    data.append(np.random.multivariate_normal(m, sig3, n))

z = np.vstack(data)

df = pd.DataFrame({'x': z[:, 0], 'y': z[:, 1]})
sns.scatterplot(df, x='x', y='y', alpha=0.5)
df.to_csv(
    '~/Workspace/projects/wbrgmm/WassersteinBayesRepulsiveGMM/data/sim_data_new_2.csv',
    index=False
)
# Out:
# [ 49  56  89 106]
# [0.16666666666666666, 0.16666666666666666, 0.3333333333333333, 0.3333333333333333]

# %%
np.random.seed(222)

m1 = np.array([0, 0])
m2 = np.array([0, 0])
m3 = [-15, 0]
sig1 = np.array([[100, 0], [0, 1]])
sig2 = np.array([[1, 0], [0, 100]])
sig3 = [[4, 1], [1, 4]]

K = 3
# ww = scipy.stats.dirichlet(np.ones(K)).rvs(1)
ww = [1/8, 1/8, 1/4, 1/4, 1/4]
nn = scipy.stats.multinomial.rvs(400, ww)
print(nn)

x1 = np.random.multivariate_normal(m1, sig1, nn[0])
x2 = np.random.multivariate_normal(m2, sig2, nn[1]) 
data = [x1, x2]

print(ww)
for n in nn[2:]: 
    m = np.random.multivariate_normal([0, 0], [[100, 0], [0, 100]])
    data.append(np.random.multivariate_normal(m, sig3, n))

z = np.vstack(data)

df = pd.DataFrame({'x': z[:, 0], 'y': z[:, 1]})
sns.scatterplot(df, x='x', y='y', alpha=0.5)
df.to_csv(
    '~/Workspace/projects/wbrgmm/WassersteinBayesRepulsiveGMM/data/sim_data_new_3.csv',
    index=False
)
# Out:
# [ 49  56  99  90 106]
# [0.125, 0.125, 0.25, 0.25, 0.25]

# %%
np.random.seed(110)

m1 = np.array([0, 0])
m2 = np.array([0, 0])
m3 = [-15, 0]
sig1 = np.array([[100, 0], [0, 1]])
sig2 = np.array([[1, 0], [0, 100]])
sig3 = [[4, 1], [1, 4]]

K = 4
# ww = scipy.stats.dirichlet(np.ones(K)).rvs(1)
ww = [1/10, 1/10, 1/5, 1/5, 1/5, 1/5]
nn = scipy.stats.multinomial.rvs(500, ww)
print(nn)

x1 = np.random.multivariate_normal(m1, sig1, nn[0])
x2 = np.random.multivariate_normal(m2, sig2, nn[1]) 
data = [x1, x2]

print(ww)
for n in nn[2:]: 
    m = np.random.multivariate_normal([0, 0], [[100, 0], [0, 100]])
    data.append(np.random.multivariate_normal(m, sig3, n))

z = np.vstack(data)

df = pd.DataFrame({'x': z[:, 0], 'y': z[:, 1]})
sns.scatterplot(df, x='x', y='y', alpha=0.5)
df.to_csv(
    '~/Workspace/projects/wbrgmm/WassersteinBayesRepulsiveGMM/data/sim_data_new_4.csv',
    index=False
)
# Out:
# [ 46  52 118 106  94  84]
# [0.1, 0.1, 0.2, 0.2, 0.2, 0.2]

# %%
from scipy.stats import invwishart

np.random.seed(110)

m1 = np.array([0, 0])
m2 = np.array([0, 0]) 
sig1 = np.array([[100, 0], [0, 1]])
sig2 = np.array([[1, 0], [0, 100]])
sig3 = [[10, 5], [5, 10]]

K = 4
# ww = scipy.stats.dirichlet(np.ones(K)).rvs(1)
ww = [1/10, 1/10, 1/5, 1/5, 1/5, 1/5]
nn = scipy.stats.multinomial.rvs(500, ww)
print(nn)

x1 = np.random.multivariate_normal(m1, sig1, nn[0])
x2 = np.random.multivariate_normal(m2, sig2, nn[1]) 
data = [x1, x2]

print(ww)
for i, n in enumerate(nn[2:]): 
    m = np.random.multivariate_normal([0, 0], [[100, 0], [0, 100]])
    sig = invwishart.rvs(5, sig3, 1)
    data.append(np.random.multivariate_normal(m, sig3, n))

z = np.vstack(data)

df = pd.DataFrame({'x': z[:, 0], 'y': z[:, 1]})
sns.scatterplot(df, x='x', y='y', alpha=0.5)
df.to_csv(
    '~/Workspace/projects/wbrgmm/WassersteinBayesRepulsiveGMM/data/sim_data_new_5.csv',
    index=False
)
# Out:
# [ 46  52 118 106  94  84]
# [0.1, 0.1, 0.2, 0.2, 0.2, 0.2]

# %%
from scipy.stats import invwishart

np.random.seed(110)

m1 = np.array([0, 0])
m2 = np.array([0, 0]) 
sig1 = np.array([[100, 0], [0, 1]])
sig2 = np.array([[1, 0], [0, 100]])
sig3 = [[10, 8], [8, 10]]

K = 4
# ww = scipy.stats.dirichlet(np.ones(K)).rvs(1)
ww = [1/12, 1/12, 1/6, 1/6, 1/6, 1/6, 1/6]
nn = scipy.stats.multinomial.rvs(500, ww)
print(nn)

x1 = np.random.multivariate_normal(m1, sig1, nn[0])
x2 = np.random.multivariate_normal(m2, sig2, nn[1]) 
data = [x1, x2]
C = [0] * nn[0] + [1] * nn[1]
gauss = [(m1, sig1), (m2, sig2)]

print(ww)
for i, n in enumerate(nn[2:]): 
    m = np.random.multivariate_normal([0, 0], [[100, 0], [0, 100]])
    sig = invwishart.rvs(2, sig3, 1)
    C += [i+2] * n
    gauss.append((m, sig))
    data.append(np.random.multivariate_normal(m, sig3, n))

z = np.vstack(data)

df = pd.DataFrame({'x': z[:, 0], 'y': z[:, 1], 'C': C})
sns.scatterplot(df, x='x', y='y', alpha=0.5)
df.to_csv(
    '~/Workspace/projects/wbrgmm/WassersteinBayesRepulsiveGMM/data/sim_data_new_6.csv',
    index=False
)
# Out:
# [ 37  45 100  91  81  76  70]
# [0.08333333333333333, 0.08333333333333333, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666, 0.16666666666666666]

# %%
from scipy.stats import invwishart

np.random.seed(110)

m1 = np.array([0, 0])
m2 = np.array([0, 0]) 
sig1 = np.array([[100, 0], [0, 1]])
sig2 = np.array([[1, 0], [0, 100]])
sig3 = [[10, 8], [8, 10]]

K = 4
# ww = scipy.stats.dirichlet(np.ones(K)).rvs(1)
ww = [1/8, 1/8, 1/4, 1/4, 1/4]
nn = scipy.stats.multinomial.rvs(500, ww)
print(nn)

x1 = np.random.multivariate_normal(m1, sig1, nn[0])
x2 = np.random.multivariate_normal(m2, sig2, nn[1]) 
data = [x1, x2]

print(ww)
for n in nn[2:]: 
    m = np.random.multivariate_normal([0, 0], [[100, 0], [0, 100]])
    sig = invwishart.rvs(10, sig3, 1)
    data.append(np.random.multivariate_normal(m, sig3, n))

z = np.vstack(data)

df = pd.DataFrame({'x': z[:, 0], 'y': z[:, 1]})
sns.scatterplot(df, x='x', y='y', alpha=0.5)
df.to_csv(
    '~/Workspace/projects/wbrgmm/WassersteinBayesRepulsiveGMM/data/sim_data_new_7.csv',
    index=False
)
# Out:
# [ 57  65 146 128 104]
# [0.125, 0.125, 0.25, 0.25, 0.25]
